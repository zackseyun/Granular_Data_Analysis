# %%
import pandas as pd
field_data = pd.read_csv('toy_fields.csv') #data about the size of the fields in acres
org_data = pd.read_csv('toy_orgs.csv') #data about the names of the orgs and their unique id's
yield_data = pd.read_csv('toy_yields.csv') #data about the harvest details 
#field_data.info()
#org_data.info()
#yield_data.info()
yield_data.head()
# Out:
#                  crop_type  year harvest_product  total_harvested  \
# 0     CROP.CORN.COMMERCIAL  2016           grain     53290.628852
# 1     CROP.CORN.COMMERCIAL  2014           grain     40073.821554
# 2     CROP.CORN.COMMERCIAL  2015           grain     45528.033941
# 3  CROP.SOYBEAN.COMMERCIAL  2015           grain     13927.332280
# 4     CROP.CORN.COMMERCIAL  2014           grain     59676.634874
#
#   harvested_unit  planted_area  harvested_area  \
# 0             bu     40.380000           560.0
# 1             bu           NaN             NaN
# 2             bu    148.610000             NaN
# 3             bu     25.000000             NaN
# 4             bu      5.026942             NaN
#
#                                    field_id  \
# 0  cb1e3bd821dd673a0c378b16ba97075919aa993a
# 1  58d04a7094c1b08e9856932a02104d2a36b7b8ce
# 2  5e3babe7b318f4245ceb16718665af0b54335443
# 3  02dc3fe6f889f3ece8daf456d26464d381bc9e55
# 4  109e500b323e0ef7baadd4409830c7619d8cfbfa
#
#                                      org_id
# 0  0966e34316e39217e4f26fbe20fc14e24c26567b
# 1  726cce9d9800d792d1e0fbb83923ac4c6be4f668
# 2  598d17ec200eeb9e27ae829746ccf47c57761bc1
# 3  fe62dee029474d52346542845674529025594056
# 4  fe62dee029474d52346542845674529025594056

# %% [markdown]
# #### hm. right away I can see some NaN values that warrant some attention. The missing entries tells me that the quality of this data quality is imperfect. I'll have to decide later on whether I want to discard those specific data rows or fill them in somehow. Also, another point of concern is the planted area and harvested area values. In the 1st row, 'planted_area' should not exceed the value of 'harvested_area'. The quality of this data may prove to be invalid should these entries are unable to be handled.

# %%
updated_harvest_area = []
updated_planted_area = []
for index,row in yield_data.iterrows():
    if row['planted_area']==float('nan')or row['harvested_area']>row['planted_area']:
        updated_harvest_area.append(None)
        updated_planted_area.append(None)
    else:
        updated_harvest_area.append(row['harvested_area'])
        updated_planted_area.append(row['planted_area'])
         
yield_data['cleaned_planted_area'] = updated_planted_area
yield_data['cleaned_harvest_area'] = updated_harvest_area  
yield_data[:5]
# Out:
#                    crop_type  year harvest_product  total_harvested  \
# 38      CROP.CORN.COMMERCIAL  2016           grain    127701.071130
# 291     CROP.CORN.COMMERCIAL  2016           grain     25602.606473
# 307  CROP.SOYBEAN.COMMERCIAL  2016           grain      8171.547260
#
#     harvested_unit  planted_area  harvested_area  cleaned_planted_area  \
# 38              bu         78.12           245.0                   NaN
# 291             bu           NaN             NaN                   NaN
# 307             bu           NaN            25.0                   NaN
#
#      cleaned_harvest_area                                  field_id  \
# 38                    NaN  66dec081f750e2d33394a88a4436242bfbdcf6da
# 291                   NaN  4da7eb451613f4e33463ea474b2d24f51d0540ff
# 307                  25.0  de5bf9fd04e342823175dba3e765c067b1e28edf
#
#                                        org_id
# 38   0966e34316e39217e4f26fbe20fc14e24c26567b
# 291  0966e34316e39217e4f26fbe20fc14e24c26567b
# 307  0966e34316e39217e4f26fbe20fc14e24c26567b

# %% [markdown]
# #### With the above forloop, I create a new column called 'updated_harvest_area' to clean the data of harvest areas that exceeded the planted area

# %%
yield_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 415 entries, 2 to 416
# Data columns (total 11 columns):
# crop_type               415 non-null object
# year                    415 non-null int64
# harvest_product         415 non-null object
# total_harvested         415 non-null float64
# harvested_unit          415 non-null object
# planted_area            304 non-null float64
# harvested_area          207 non-null float64
# field_id                415 non-null object
# org_id                  415 non-null object
# cleaned_planted_area    228 non-null float64
# cleaned_harvest_area    131 non-null float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 35.7+ KB

# %% [markdown]
# #### There were many missing values in the planted area column and the harvested area column.  After the data cleaning, 77 of both the planted_area and harvest_area entries were cleared and only (228,131) respective valid entries are remaining.

# %%
org_data.rename(columns = {'new_org_id': 'org_id'}, inplace= True)
org_data.columns
cols = yield_data.columns.tolist() # just rearranging column to make is easier to analyze
cols= cols[:5]+cols[7:]+ cols[5:7]
yield_data = yield_data[cols]
yield_data = yield_data.loc[yield_data['org_id']=='0966e34316e39217e4f26fbe20fc14e24c26567b']
yield_data.loc[yield_data['year']==2016]
# Out:
#                    crop_type  year harvest_product  total_harvested  \
# 38      CROP.CORN.COMMERCIAL  2016           grain    127701.071130
# 291     CROP.CORN.COMMERCIAL  2016           grain     25602.606473
# 307  CROP.SOYBEAN.COMMERCIAL  2016           grain      8171.547260
#
#     harvested_unit  planted_area  harvested_area  cleaned_planted_area  \
# 38              bu         78.12           245.0                   NaN
# 291             bu           NaN             NaN                   NaN
# 307             bu           NaN            25.0                   NaN
#
#      cleaned_harvest_area                                  field_id  \
# 38                    NaN  66dec081f750e2d33394a88a4436242bfbdcf6da
# 291                   NaN  4da7eb451613f4e33463ea474b2d24f51d0540ff
# 307                  25.0  de5bf9fd04e342823175dba3e765c067b1e28edf
#
#                                        org_id
# 38   0966e34316e39217e4f26fbe20fc14e24c26567b
# 291  0966e34316e39217e4f26fbe20fc14e24c26567b
# 307  0966e34316e39217e4f26fbe20fc14e24c26567b

# %% [markdown]
# #### we have to rename the 'organization_id' column in our toy_org.csv file to 'org_id' to be able to merge the two data frames

# %%
mergedDf = pd.merge(yield_data,org_data, left_on = ['org_id'],right_on = ['org_id'])
mergedDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 415 entries, 0 to 414
# Data columns (total 13 columns):
# crop_type               415 non-null object
# year                    415 non-null int64
# harvest_product         415 non-null object
# total_harvested         415 non-null float64
# harvested_unit          415 non-null object
# field_id                415 non-null object
# org_id                  415 non-null object
# cleaned_planted_area    228 non-null float64
# cleaned_harvest_area    131 non-null float64
# planted_area            304 non-null float64
# harvested_area          207 non-null float64
# grower                  415 non-null object
# organization_id         415 non-null object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 45.4+ KB

# %%
mergedDf[:5]
# Out:
#                  crop_type  year harvest_product  total_harvested  \
# 0     CROP.CORN.COMMERCIAL  2015           grain     45528.033941
# 1  CROP.SOYBEAN.COMMERCIAL  2015           grain     30341.901524
# 2     CROP.CORN.COMMERCIAL  2015           grain     50987.861543
# 3  CROP.SOYBEAN.COMMERCIAL  2015           grain     13685.647874
# 4  CROP.SOYBEAN.COMMERCIAL  2017           grain     30074.126012
#
#   harvested_unit                                  field_id  \
# 0             bu  5e3babe7b318f4245ceb16718665af0b54335443
# 1             bu  ed7e44f184a071a25c905e1ee9f73c6741e0bd01
# 2             bu  fd72b33016dc565f97e287594573282d0ae29f08
# 3             bu  6682442ec01eee124d9a2b40f049d2036596b969
# 4             bu  daeab438051b9d0a654659b7f038f08b44c184af
#
#                                      org_id  cleaned_planted_area  \
# 0  598d17ec200eeb9e27ae829746ccf47c57761bc1                148.61
# 1  598d17ec200eeb9e27ae829746ccf47c57761bc1                 80.21
# 2  598d17ec200eeb9e27ae829746ccf47c57761bc1                179.12
# 3  598d17ec200eeb9e27ae829746ccf47c57761bc1                133.62
# 4  598d17ec200eeb9e27ae829746ccf47c57761bc1                   NaN
#
#    cleaned_harvest_area  planted_area  harvested_area        grower  \
# 0                   NaN        148.61             NaN  Simmons Farm
# 1                   NaN         80.21             NaN  Simmons Farm
# 2                   NaN        179.12             NaN  Simmons Farm
# 3                   NaN        133.62             NaN  Simmons Farm
# 4                   NaN         52.47            56.0  Simmons Farm
#
#                         organization_id
# 0  1a40b159-81f6-4019-a6db-6af405a748d7
# 1  1a40b159-81f6-4019-a6db-6af405a748d7
# 2  1a40b159-81f6-4019-a6db-6af405a748d7
# 3  1a40b159-81f6-4019-a6db-6af405a748d7
# 4  1a40b159-81f6-4019-a6db-6af405a748d7

# %%
mergedDf.grower.value_counts()
# Out:
# Simmons Farm        148
# Cavanaugh Farm       82
# Dudley Farm          51
# Austin Farm          50
# Depner Farm          34
# Konecny Farm          8
# Jenkins Farm          7
# Odell Farm            6
# Hawker Farm           5
# Ross Farm             4
# Gregory Farm          4
# Overholt Farm         3
# Flanagan Farm         3
# Sifuentes Farm        2
# Mull Farm             2
# Seever Farm           2
# Barrocas Farm         2
# Carpentieri Farm      1
# Crawford Farm         1
# Batte Farm            1
# Stinson Farm          1
# Name: grower, dtype: int64

# %%
mergedDf.loc[mergedDf['grower']=='Austin Farm']
# Out:
#                    crop_type  year harvest_product  total_harvested  \
# 269  CROP.SOYBEAN.COMMERCIAL  2015           grain       403.185902
# 270  CROP.SOYBEAN.COMMERCIAL  2015           grain     27620.687600
# 271     CROP.CORN.COMMERCIAL  2015           grain     41322.024805
# 272  CROP.SOYBEAN.COMMERCIAL  2015           grain     13638.816380
# 273     CROP.CORN.COMMERCIAL  2015           grain     48335.168466
# 274     CROP.CORN.COMMERCIAL  2015           grain    102959.162415
# 311             bu  de5bf9fd04e342823175dba3e765c067b1e28edf
# 312             bu  5326c640348588b6c69ff9662ad0dfa6c2b1597f
# 313             bu  373b845a8eb362f8dd343300874f1cb424d3d62c
# 314             bu  62e2c677118c2b78f17c6ff57f42928173947564
# 315             bu  d8bcc52defbf56e86d79dd3213d2dc422e7591b2
# 316             bu  8dd2c1528419d4fcf5c05853c23dbeecc8d5768e
# 317             bu  d1170f65e62dbdbb6abfdb0b72c3039126c88169
#
#                                        org_id  cleaned_planted_area  \
# 269  0966e34316e39217e4f26fbe20fc14e24c26567b                 57.82
# 270  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 271  0966e34316e39217e4f26fbe20fc14e24c26567b                 62.31
# 272  0966e34316e39217e4f26fbe20fc14e24c26567b                100.00
# 273  0966e34316e39217e4f26fbe20fc14e24c26567b                121.10
# 274  0966e34316e39217e4f26fbe20fc14e24c26567b                159.98
# 275  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 276  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 277  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 278  0966e34316e39217e4f26fbe20fc14e24c26567b                139.75
# 279  0966e34316e39217e4f26fbe20fc14e24c26567b                154.11
# 280  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 281  0966e34316e39217e4f26fbe20fc14e24c26567b                 66.01
# 282  0966e34316e39217e4f26fbe20fc14e24c26567b                  5.75
# 283  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 284  0966e34316e39217e4f26fbe20fc14e24c26567b                  4.00
# 285  0966e34316e39217e4f26fbe20fc14e24c26567b                144.01
# 286  0966e34316e39217e4f26fbe20fc14e24c26567b                 10.50
# 287  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 288  0966e34316e39217e4f26fbe20fc14e24c26567b                 82.00
# 289  0966e34316e39217e4f26fbe20fc14e24c26567b                 61.56
# 290  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 291  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 292  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 293  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 294  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 295  0966e34316e39217e4f26fbe20fc14e24c26567b                 31.32
# 296  0966e34316e39217e4f26fbe20fc14e24c26567b                  7.89
# 297  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 298  0966e34316e39217e4f26fbe20fc14e24c26567b                150.11
# 299  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 300  0966e34316e39217e4f26fbe20fc14e24c26567b                 76.01
# 301  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 302  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 303  0966e34316e39217e4f26fbe20fc14e24c26567b                 11.00
# 304  0966e34316e39217e4f26fbe20fc14e24c26567b                150.01
# 305  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 306  0966e34316e39217e4f26fbe20fc14e24c26567b                 40.00
# 307  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 308  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 309  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 310  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 311  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 312  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 313  0966e34316e39217e4f26fbe20fc14e24c26567b                 29.00
# 314  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
# 315  0966e34316e39217e4f26fbe20fc14e24c26567b                127.89
# 316  0966e34316e39217e4f26fbe20fc14e24c26567b                140.89
# 317  0966e34316e39217e4f26fbe20fc14e24c26567b                   NaN
#
#      cleaned_harvest_area  planted_area  harvested_area       grower  \
# 269                 57.82         57.82           57.82  Austin Farm
# 270                   NaN         40.00           40.38  Austin Farm
# 271                 62.11         62.31           62.11  Austin Farm
# 272                 99.00        100.00           99.00  Austin Farm
# 273                121.00        121.10          121.00  Austin Farm
# 274                159.77        159.98          159.77  Austin Farm
# 275                   NaN         78.12          245.00  Austin Farm
# 276                   NaN         42.21           42.25  Austin Farm
# 277                   NaN         68.00           68.34  Austin Farm
# 278                139.44        139.75          139.44  Austin Farm
# 279                153.80        154.11          153.80  Austin Farm
# 280                   NaN        155.56          156.20  Austin Farm
# 281                 65.00         66.01           65.00  Austin Farm
# 282                  5.54          5.75            5.54  Austin Farm
# 283                   NaN         40.00           40.80  Austin Farm
# 284                  3.97          4.00            3.97  Austin Farm
# 285                144.00        144.01          144.00  Austin Farm
# 286                 10.48         10.50           10.48  Austin Farm
# 287                   NaN        152.08          152.70  Austin Farm
# 288                 81.22         82.00           81.22  Austin Farm
# 289                 61.03         61.56           61.03  Austin Farm
# 290                   NaN        301.22          303.80  Austin Farm
# 291                   NaN        151.00          151.06  Austin Farm
# 292                   NaN        135.55          136.60  Austin Farm
# 293                   NaN         72.00           72.11  Austin Farm
# 294                   NaN         56.00           56.74  Austin Farm
# 295                 31.32         31.32           31.32  Austin Farm
# 296                  7.68          7.89            7.68  Austin Farm
# 297                   NaN         97.27           99.86  Austin Farm
# 298                149.50        150.11          149.50  Austin Farm
# 299                   NaN        155.60          155.63  Austin Farm
# 300                 75.61         76.01           75.61  Austin Farm
# 301                   NaN         56.00           56.54  Austin Farm
# 302                   NaN        158.08          158.10  Austin Farm
# 303                 10.85         11.00           10.85  Austin Farm
# 304                150.00        150.01          150.00  Austin Farm
# 305                   NaN        115.00          115.14  Austin Farm
# 306                 39.96         40.00           39.96  Austin Farm
# 307                   NaN         92.00           92.12  Austin Farm
# 308                   NaN         86.00           86.76  Austin Farm
# 309                   NaN           NaN             NaN  Austin Farm
# 310                   NaN        103.43          103.82  Austin Farm
# 311                 25.00           NaN           25.00  Austin Farm
# 312                   NaN         52.00           52.02  Austin Farm
# 313                 28.49         29.00           28.49  Austin Farm
# 314                   NaN         50.00           50.31  Austin Farm
# 315                127.31        127.89          127.31  Austin Farm
# 316                139.18        140.89          139.18  Austin Farm
# 317                   NaN         40.12           43.95  Austin Farm
#
#                           organization_id
# 269  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 270  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 271  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 272  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 273  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 274  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 275  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 276  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 277  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 278  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 279  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 280  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 281  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 282  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 283  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 284  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 285  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 286  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 287  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 288  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 289  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 290  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 291  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 292  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 293  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 294  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 295  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 296  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 297  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 298  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 299  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 300  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 301  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 302  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 303  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 304  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 305  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 306  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 307  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 308  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 309  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 310  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 311  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 312  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 313  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 314  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 315  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 316  c9a331d4-68fb-4946-9e4e-fdca1eb268b3
# 317  c9a331d4-68fb-4946-9e4e-fdca1eb268b3

# %%
mergedDf.loc[mergedDf['grower']=='Dudley Farm'].year.value_counts()
# Out:
# 2015    33
# 2014    17
# Name: year, dtype: int64

# %% [markdown]
# #### With this I can tell that several entries are created for the same year, that could have otherwise been compacted. this can most likely be compacted using the groupby function and specificying which featured we want to see the compacted values for.

# %%
mergedDf.groupby(['grower','year'])['total_harvested','cleaned_planted_area','cleaned_harvest_area'].sum()
# Out:
#                        total_harvested  cleaned_planted_area  \
# grower           year
# Austin Farm      2015     2.038052e+06           1933.020000
#                  2016     1.614752e+05              0.000000
# Barrocas Farm    2017     1.174206e+05              0.000000
# Batte Farm       2017     7.047084e+04              0.000000
# Carpentieri Farm 2016     7.119898e+04              0.000000
# Cavanaugh Farm   2014     3.929600e+05             39.808568
#                  2015     1.589323e+06            380.285906
#                  2016     1.144137e+06            730.520000
#                  2017     1.266030e+06            519.270000
# Crawford Farm    2017     9.469835e+04              0.000000
# Depner Farm      2014     5.356606e+05           1035.128219
#                  2015     6.691972e+05            577.779999
#                  2016     2.044040e+05              0.000000
#                  2017     3.375841e+05            105.532126
# Dudley Farm      2014     8.032012e+05              0.000000
#                  2015     1.218157e+06           3452.780000
# Flanagan Farm    2015     4.109234e+04            100.630000
#                  2016     3.839162e+04             77.320000
# Gregory Farm     2015     1.991505e+05              0.000000
#                  2017     2.069695e+04              0.000000
# Hawker Farm      2015     7.485965e+04            114.750000
#                  2016     3.674980e+04            249.850000
#                  2017     6.697064e+04              0.000000
# Jenkins Farm     2016     2.321079e+05            269.497784
# Konecny Farm     2017     3.269919e+05              0.000000
# Mull Farm        2017     4.219978e+04              0.000000
# Odell Farm       2014     1.784253e+05             12.000000
#                  2016     9.191359e+04              0.000000
#                  2017     1.046427e+05             10.000000
# Overholt Farm    2017     2.207304e+05             60.000000
# Ross Farm        2017     1.619524e+05             61.720000
# Seever Farm      2017     2.226073e+05             56.000000
# Sifuentes Farm   2017     4.454520e+04              0.470000
# Simmons Farm     2015     2.582268e+06           5473.190000
#                  2016     2.221029e+06           2829.544397
#                  2017     1.738078e+06           3909.710227
# Stinson Farm     2017     8.186285e+04             10.490000
#
#                        cleaned_harvest_area
# grower           year
# Austin Farm      2015           1924.080000
#                  2016             25.000000
# Barrocas Farm    2017            147.000000
# Batte Farm       2017             13.000000
# Carpentieri Farm 2016              0.000000
# Cavanaugh Farm   2014              0.000000
#                  2015           1544.010000
#                  2016            598.662117
#                  2017            100.000000
# Crawford Farm    2017            150.000000
# Depner Farm      2014            199.770000
#                  2015             12.300000
#                  2016            387.800000
#                  2017            200.000000
# Dudley Farm      2014            378.000000
#                  2015            436.700000
# Flanagan Farm    2015              0.000000
#                  2016              0.000000
# Gregory Farm     2015            309.500000
#                  2017              0.000000
# Hawker Farm      2015            114.390000
#                  2016            144.000000
#                  2017              0.000000
# Jenkins Farm     2016             93.000000
# Konecny Farm     2017            184.000000
# Mull Farm        2017            296.000000
# Odell Farm       2014            119.000000
#                  2016              0.000000
#                  2017              0.000000
# Overholt Farm    2017              0.000000
# Ross Farm        2017             58.890000
# Seever Farm      2017              0.000000
# Sifuentes Farm   2017              0.000000
# Simmons Farm     2015            290.550000
#                  2016           2763.638541
#                  2017           2716.744000
# Stinson Farm     2017             10.490000

# %% [markdown]
# ## It is hard to say whether the data quality is necessarily good or bad. The entries could be more secure to make the dataset more pure and so that it can be trusted with full confidence. That said, it is still possible to be able to compare valid yield data between the farms and see which ones perform the best.
